# %% [markdown]
# # SVM Primal vs Dual
# ## 1. Theory
# The SVM objective can be formulated in two ways: the primal form handling weights directly, and the dual form utilizing Lagrangian multipliers to enable the kernel trick.

# %% [markdown]
# ## 2. Implementation
# We will implement this from scratch using NumPy.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your implementation goes here

# %% [markdown]
# ## 3. Visualization
# Let's visualize the results.

# %%
# plt.plot(...)
