# %% [markdown]
# # Activation Analysis
# ## 1. Theory
# Analyzing activation functions like ReLU, Sigmoid and Tanh. Discusses the vanishing gradient problem and dead ReLUs.

# %% [markdown]
# ## 2. Implementation
# We will implement this from scratch using NumPy.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your implementation goes here

# %% [markdown]
# ## 3. Visualization
# Let's visualize the results.

# %%
# plt.plot(...)
