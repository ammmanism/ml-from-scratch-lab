# %% [markdown]
# # MLP Backpropagation
# ## 1. Theory
# Backpropagation computes the gradient of the loss function with respect to the weights of the network. The Chain Rule is used extensively.

# %% [markdown]
# ## 2. Implementation
# We will implement this from scratch using NumPy.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your implementation goes here

# %% [markdown]
# ## 3. Visualization
# Let's visualize the results.

# %%
# plt.plot(...)
