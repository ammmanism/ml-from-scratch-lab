# %% [markdown]
# # Bias Variance Tradeoff
# ## 1. Theory
# Using polynomial regression to demonstrate underfitting (high bias) and overfitting (high variance).

# %% [markdown]
# ## 2. Implementation
# We will implement this from scratch using NumPy.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your implementation goes here

# %% [markdown]
# ## 3. Visualization
# Let's visualize the results.

# %%
# plt.plot(...)
